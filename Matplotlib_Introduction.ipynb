# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# Out:
# C:\Users\asus\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
x = np.random.randint(10,1000,40)
y = np.random.randint(5,200,40)

# %%
plt.plot(x,y)

# %%
# plt.plot(x,y,'o')
plt.plot(x,y,'ro')

# %%
plt.scatter(x,y,color='black')

# %%
df = pd.read_csv('dataset/ipl/matches.csv')

# %%
pd.value_counts(df['toss_decision'])
# Out:
# field    315
# bat      262
# Name: toss_decision, dtype: int64

# %%
labels = np.array(['field','bat'])
x = np.array([315,262])

# %%
plt.pie(x)
# Out:
# ([<matplotlib.patches.Wedge at 0x233a29bd5f8>,
# ...
#  [Text(-0.1581629911282015, 1.0885699188556428, ''),
#   Text(0.1581630930474717, -1.08856990404735, '')])

# %%
plt.pie(x,labels=labels, autopct='%.2f%%', startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x233a48b3cf8>,
# ...
#  [Text(-1.0885699188556428, -0.1581629911282012, 'field'),
#   Text(1.08856990404735, 0.15816309304747164, 'bat')],
#  [Text(-0.593765410284896, -0.08627072243356428, '54.59%'),
#   Text(0.5937654022076454, 0.08627077802589361, '45.41%')])
